# %% [markdown]
# # Plots for figure 1d

# %% [markdown]
# # 500 G:
#
# G:\data\Membrane 191-8\immersion oil\1jM\NV1\XY8-35.pyd contrast 34.2 depth 5.0+-0.3
# G:\data\Membrane 191-8\immersion oil\4jN\NV3\xy8-8.pyd contrast 29.6 depth 2.9+-0.2
#
#
# # 601.4 G:
#
# G:\data\Membrane 191 p+\immersion oil\autopilot\NV5\xy8-30.pyd contrast 37.0
# G:\data\Membrane 191 p+\immersion oil\autopilot\NV7\xy8-12.pyd contrast 35.7
#
# # 624.1 G:
#
# G:\data\Membrane 191-8\immersion oil2\1jM NV1\xy8-30_oil.pyd contrast 40.9
# G:\data\Membrane 191-8\immersion oil2\4jN NV3\xy8-10.pyd contrast 32.1

# %%
my_files = ['G:/data/Membrane 191-8/immersion oil/1jM/NV1/XY8-35.pyd',
            'G:/data/Membrane 191-8/immersion oil/4jN/NV3/xy8-8.pyd',
            'G:/data/Membrane 191 p+/immersion oil/autopilot/NV5/xy8-30.pyd',
            'G:/data/Membrane 191 p+/immersion oil/autopilot/NV7/xy8-12.pyd',
            'G:/data/Membrane 191-8/immersion oil2/1jM NV1/xy8-30_oil.pyd',
            'G:/data/Membrane 191-8/immersion oil2/4jN NV3/xy8-10.pyd']
contrast = [34.2, 29.6, 37.0, 35.7, 40.9, 32.1]

# %%
import pickle
normalized_counts=[]
freq=[]

for i in range(len(my_files)):   
    File1=open(my_files[i],'rb')
    File=File1.read()
    File=File.decode().replace('\r\n', '\n')
    File1.close()
    data_new = pickle.load(File)
#     with open(my_files[i],'rb') as f:
#         data_new = pickle.load(f)
    rabi_contrast=contrast[i]
    N1 = File2['measurement']['pulse_num']
    counts=File2['fit']['spin_state1']
    counts2= File2['fit']['spin_state2']
    time= File2['measurement']['tau']
    pi_pulse=File2['measurement']['pi_1']
    l=(counts+counts2)/2.
    baseline=sum(l)/len(l)
    C0_up = baseline/(1-0.01*rabi_contrast/2)
    C0_down = C0_up*(1-0.01*rabi_contrast)
    counts=counts2-counts
    normalized_counts.append((counts2-baseline)/(C0_up-baseline))
    tau=(2*time+pi_pulse)# in nseconds   
    freq.append((1.0/(2*tau))*1e+3)
# Out:
# Traceback (most recent call last):
#   File "C:\Users\pi3\Documents\GitHub\qudi\logic\jupyterkernel\qzmqkernel.py", line 795, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-62-de38b60ca79c>", line 10, in <module>
#     data_new = pickle.load(File)
# TypeError: file must have 'read' and 'readline' attributes

# %%
File1=open(my_files[i],'rb')
File=File1.read()

print(File)
# Out:
# b'(dp1\r\nS\'fit\'\r\np2\r\n(dp3\r\nS\'spin_state_error2\'\r\np4\r\ncnumpy.core.multiarray\r\n_reconstruct\r\np5\r\n(cnumpy\r\nndarray\r\np6\r\n(I0\r\ntS\'b\'\r\ntRp7\r\n(I1\r\n(I21\r\ntcnumpy\r\ndtype\r\np8\r\n(S\'f8\'\r\nI0\r\nI1\r\ntRp9\r\n(I3\r\nS\'<\'\r\nNNNI-1\r\nI-1\r\nI0\r\ntbI00\r\nS\'\\xff[\\x83\\xf5\\xc8"d@P\\x13\\xb2\\xeaS\\x0ed@`\\x12\\x15/\\xcd\\nd@\\xca\\xa2}^\\x17\\x13d@\\xf6@ \\xbe\\x1f\\xf8c@=E\\\\w\\x15\\x0ed@v\\xc4!}\\xe4\\xf5c@\\x98\\x01u\\xc5\\xe9\\xe8c@u\\\\\\x80#W\\xc6c@W\\x06\\x13\\xf3\\xaf\\xc3c@]\\xf8\\xdc\\xdf`ec@\\x9a\\n\\xfc\\x17\\xd7\\nc@\\xae\\x1b"\\xa3\\xa4\\xa5c@\\x97:\\xe1\\x86P\\xf8c@m\\xb0\\xaa6R\\xfbc@\\xbb\\xbd\\x90\\x1f\\xb1\\x11d@\\x11*\\xc8z\\t\\xe5c@0t\\x05\\x01q"d@\\x11\\xddt4\\xb2\\x06d@\\x8b\\xf3X"kHd@\\xc9ch\\xa2;&d@\'\r\ntbsS\'spin_state_error1\'\r\np10\r\ng5\r\n(g6\r\n(I0\r\ntS\'b\'\r\ntRp11\r\n(I1\r\n(I21\r\ntg9\r\nI00\r\nS"\\xed\\x13^\\xc5\\xda\\xfe`@C\\xab\\x7f\\xb3\\x8b\\xe9`@\\x1c\\x99\\x9a,\\xea/a@\\xcb\\xe5\\xf6\\t\\xb8\\xf0`@\\xbbv\\x91<\\x84 a@\\x84_>X\\x9d5a@\\xc4g\\xb3\\x0b ?a@\\r\\xb4\\xc6\\xeb\\xc7:a@\\xbf\\xc0F\\x96%_a@\\xce\\x9c\\xf6\\xe7oza@\\x0f\\xdc\\xb5\\r\\xbe\\xdca@\\x978{a\\xde\'b@\\xb3u\\xf7\\xa7E\\xa6a@`\\x80]\\xff\\n2a@\\x83\\xcfc\\xad\\x86%a@\\x19`\\x1e\\x17o a@\\xd2\\x8c,aD\\ra@\\xce3\\n[\\x03\\xd9`@J\\xac\\xe5\\n<\\x04a@e1\'\\xfa\\x8f\\x15a@\\x18~\\x03]\\xd8\\x0ca@"\r\ntbsS\'position_normalize\'\r\np12\r\nF2200\r\nsS\'fit_times\'\r\np13\r\ng5\r\n(g6\r\n(I0\r\ntS\'b\'\r\ntRp14\r\n(I1\r\n(I1\r\ntg9\r\nI00\r\nS\'\\xe1e\\xa5\\xd3\\x05{m@\'\r\ntbsS\'text\'\r\np15\r\nS\'f 1: 2.358356e+02 ns, HWHM 2.525e+00 ns, contrast 71.9%\\n, freq 2.120e+00 MHz\'\r\np16\r\nsS\'fit_contrast\'\r\np17\r\ng5\r\n(g6\r\n(I0\r\ntS\'b\'\r\ntRp18\r\n(I1\r\n(I1\r\ntg9\r\nI00\r\nS\'\\x8b\\xcd\\x80\\xf2t\\xf9Q@\'\r\ntbsS\'free_evolution_time\'\r\np19\r\ng5\r\n(g6\r\n(I0\r\ntS\'b\'\r\ntRp20\r\n(I1\r\n(I21\r\ntg9\r\nI00\r\nS\'\\x85\\xebQ\\xb8\\x1e\\xcdj@\\x85\\xebQ\\xb8\\x1e\\rk@\\x85\\xebQ\\xb8\\x1eMk@\\x85\\xebQ\\xb8\\x1e\\x8dk@\\x85\\xebQ\\xb8\\x1e\\xcdk@\\x85\\xebQ\\xb8\\x1e\\rl@\\x85\\xebQ\\xb8\\x1eMl@\\x85\\xebQ\\xb8\\x1e\\x8dl@\\x85\\xebQ\\xb8\\x1e\\xcdl@\\x85\\xebQ\\xb8\\x1e\\rm@\\x85\\xebQ\\xb8\\x1eMm@\\x85\\xebQ\\xb8\\x1e\\x8dm@\\x85\\xebQ\\xb8\\x1e\\xcdm@\\x85\\xebQ\\xb8\\x1e\\rn@\\x85\\xebQ\\xb8\\x1eMn@\\x85\\xebQ\\xb8\\x1e\\x8dn@\\x85\\xebQ\\xb8\\x1e\\xcdn@\\x85\\xebQ\\xb8\\x1e\\ro@\\x85\\xebQ\\xb8\\x1eMo@\\x85\\xebQ\\xb8\\x1e\\x8do@\\x85\\xebQ\\xb8\\x1e\\xcdo@\'\r\ntbsS\'spin_state1\'\r\np21\r\ng5\r\n(g6\r\n(I0\r\ntS\'b\'\r\ntRp22\r\n(I1\r\n(I21\r\ntg9\r\nI00\r\nS"\\x98\\xdee\\xf8\\x90\\r\\xd2@\\x8a\\x03\\x8f`h\\xe0\\xd1@\\xc6\\xea\\xf1\\x1bav\\xd2@\\xb8\\x9f]\\xad\\x95\\xef\\xd1@nJ\\xec\\x15[U\\xd2@\\xe1}\\xf8\\x03\\xa2\\x82\\xd2@\'\\x90y%\\x1d\\x97\\xd2@\\xb6\\xa55\\xc8\\xc0\\x8d\\xd2@Q.\\x07\\xaee\\xdc\\xd2@\\xad-\\x8c\\xba\\xd6\\x17\\xd3@n\\x02mP\\xf9\\xf0\\xd3@uK\\x83\\xb3\\x17\\x9a\\xd4@\\x81hz\\xeb\\x13x\\xd3@PHj\\xe3\\xf3z\\xd2@6\\xa6\\xc33\\x16`\\xd2@\\x9cV\\x80\\xd0-U\\xd2@\\xec\\xcf\\xc0N<,\\xd2@\\x84\\x90\\x1a!\\x86\\xbd\\xd1@\\xb5\\xd2\\x0e\\xb6\\x00\\x19\\xd2@\\x9c\\x86\\x93\\x02\\xef=\\xd2@\\xac\\xc2\\xa0\\x15V+\\xd2@"\r\ntbsS\'fit_parameters\'\r\np23\r\ng5\r\n(g6\r\n(I0\r\ntS\'b\'\r\ntRp24\r\n(I1\r\n(I4\r\ntg9\r\nI00\r\nS\'\\x18\\x0bV\\xb0!\\xfe\\xea?\\xe1e\\xa5\\xd3\\x05{m@\\x9df_U\\xd0\\xf9\\x03@\\xac\\xc8;\\xb9\\xa7\\x07\\x13\\xc0\'\r\ntbsS\'pulse\'\r\np25\r\ng5\r\n(g6\r\n(I0\r\ntS\'b\'\r\ntRp26\r\n(I1\r\n(I960\r\ntg9\r\nI00\r\nS\'\\x00\\x00\\x00\\x00\\x00\\x00,@\\x00\\x00\\x00\\x00\\x00\\x00,@\\x00\\x00\\x00\\x00\\x00\\x00\\x08@\\x00\\x00\\x00\\x00\\x00\\x00\\x14@\\x00\\x00\\x00\\x00\\x00\\x00(@\\x00\\x00\\x00\\x00\\x00\\x00\\x1c@\\x00\\x00\\x00\\x00\\x00\\x00\\x14@\\x00\\x00\\x00\\x00\\x00\\x00$@\\x00\\x00\\x00\\x00\\x00\\x00&@\\x00\\x00\\x00\\x00\\x00\\x00"@\\x00\\x00\\x00\\x00\\x00\\x00\\x10@\\x00\\x00\\x00\\x00\\x00\\x00"@\\x00\\x00\\x00\\x00\\x00\\x00"@\\x00\\x00\\x00\\x00\\x00\\x00\\x14@\\x00\\x00\\x00\\x00\\x00\\x00"@\\x00\\x00\\x00\\x00\\x00\\ ...

# %%
import numpy as np

# for i in range(len(my_files)):
myfile=my_files[0]
f = open(myfile, 'r')
lines = f.readlines()
result = []
for x in lines:
    result.append(x.split('#')[0])
f.close()
a = [x for x in result if x != '']
    
evolution_time = np.zeros(len(a))
counts1 = np.zeros(len(a))
error1 = np.zeros(len(a))
counts2 = np.zeros(len(a))
error2 = np.zeros(len(a))

for i in range(len(a)):
    evolution_time[i]=np.asarray(a[i].split(), dtype=np.float32)[0]
    counts1[i] = np.asarray(a[i].split(), dtype=np.float32)[1]
    error1[i] = np.asarray(a[i].split(), dtype=np.float32)[3]
    counts2[i] = np.asarray(a[i].split(), dtype=np.float32)[2]
    error2[i] = np.asarray(a[i].split(), dtype=np.float32)[4]

baseline = np.sum(counts2+counts1)/len(counts2)/2
C0_up = baseline / (1 - 0.01 * contrast / 2)
C0_down = C0_up * (1 - 0.01 * contrast)
counts = counts2 - counts1

T = evolution_time * 10 * N

normalized_counts = (counts) / (C0_up - C0_down)
freq=0.5/evolution_time/1.0e+6

# %%
import numpy as np

# for i in range(len(my_files)):
myfile=my_files[1]
f = open(myfile, 'r')
lines = f.readlines()
result = []
for x in lines:
    result.append(x.split('#')[0])
f.close()
a = [x for x in result if x != '']
    
evolution_time2 = np.zeros(len(a))
counts1 = np.zeros(len(a))
error1 = np.zeros(len(a))
counts2 = np.zeros(len(a))
error2 = np.zeros(len(a))

for i in range(len(a)):
    evolution_time2[i]=np.asarray(a[i].split(), dtype=np.float32)[0]
    counts1[i] = np.asarray(a[i].split(), dtype=np.float32)[1]
    error1[i] = np.asarray(a[i].split(), dtype=np.float32)[3]
    counts2[i] = np.asarray(a[i].split(), dtype=np.float32)[2]
    error2[i] = np.asarray(a[i].split(), dtype=np.float32)[4]

baseline = np.sum(counts2+counts1)/len(counts2)/2
C0_up = baseline / (1 - 0.01 * contrast / 2)
C0_down = C0_up * (1 - 0.01 * contrast)
counts = counts2 - counts1

T = evolution_time * 10 * N

normalized_counts2 = (counts) / (C0_up - C0_down)
freq=0.5/evolution_time/1.0e+6

# %%
from plotly import __version__
from plotly.offline import init_notebook_mode, plot
from plotly.graph_objs import Scatter

init_notebook_mode()

trace1 = Scatter(
    x = evolution_time*1e+6,
    y = normalized_counts-normalized_counts2,
    error_y=dict(
            type='data',
            array=error2,
            visible=True
                ),
    mode = 'lines+markers',
    name = 'lines'
)

trace2 = Scatter(
    x = evolution_time*1e+6,
    y = normalized_counts2,
    error_y=dict(
            type='data',
            array=error2,
            visible=True
                ),
    mode = 'lines+markers',
    name = 'just locking'
)
trace3 = Scatter(
    x = evolution_time*1e+6,
    y = normalized_counts,
    error_y=dict(
            type='data',
            array=error2,
            visible=True
                ),
    mode = 'lines+markers',
    name = 'with waiting'
)


plot_data = [trace2, trace3]
plot(plot_data, filename='scatter-mode')
# Out:
# 'file://C:\\Users\\pi3\\Documents\\GitHub\\qudi\\scatter-mode.html'

# %%
np.savetxt('G:/data/QudiData/2018/01/20180119/PulsedMeasurement/counts_kddxy_6_pol.txt', normalized_counts, delimiter=',')
np.savetxt('G:/data/QudiData/2018/01/20180119/PulsedMeasurement/freq_kddxy_6_pol.txt', freq, delimiter=',')

# %%
import pylab as plb
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp

x=0.5/evolution_time/1.0e+6
y=normalized_counts

n = len(x)                          #the number of data
mean = sum(x*y)/n                   #note this correction
sigma = sum(y*(x-mean)**2)/n        #note this correction

def gaus(x,a,x0,sigma):
    return y[0]-a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[0.3, 2.4, 0.1])

print(popt)
# Out:
# [ 0.15169233  2.41114487  0.05723856]

# %%
from plotly import __version__
from plotly.offline import init_notebook_mode, plot
from plotly.graph_objs import Scatter

init_notebook_mode()

# print("plotly version:", __version__)

freq=0.5/evolution_time/1.0e+6
popt=[ 0.15,  2.41,  0.03]

trace1 = Scatter(
    x = freq,
    y = normalized_counts,
    mode = 'lines+markers',
    name = 'lines+markers'
)
trace2 = Scatter(
    x = np.linspace(freq.max(), freq.min(), 200),
    y = gaus(np.linspace(freq.max(), freq.min(), 200), *popt)-0.2,
    mode = 'lines',
    name = 'lines'
)

plot_data = [trace1, trace2]
plot(plot_data, filename='scatter-mode')
# Out:
# 'file://C:\\Users\\pi3\\Documents\\GitHub\\qudi\\scatter-mode.html'

# %%
from plotly import __version__
from plotly.offline import init_notebook_mode, plot
from plotly.graph_objs import Scatter

# t=np.linspace(0, 2*4*300e-9, 200)
# y=np.sin(2*np.pi*2.4*1e+6*t)

t=np.linspace(0, 4, 200)
y=np.exp(-t)

trace = Scatter(
    x = t,
    y = y,
    mode = 'lines',
    name = 'lines'
)

plot_data = [trace]
plot(plot_data, filename='scatter-mode')
# Out:
# 'file://C:\\Users\\pi3\\Documents\\GitHub\\qudi\\scatter-mode.html'

# %%
freq
# Out:
# array([ 2.52525259,  2.51256283,  2.49999997,  2.48756212,  2.47524758,
#         2.4630542 ,  2.45098036,  2.43902432,  2.42718452,  2.41545894,
#         2.40384612,  2.39234442,  2.38095243,  2.36966825,  2.35849053,
#         2.34741776,  2.33644864,  2.3255814 ,  2.31481478,  2.30414754,
#         2.29357802])
